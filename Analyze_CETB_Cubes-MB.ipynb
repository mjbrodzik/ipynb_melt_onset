# %% [markdown]
# # Analyze_CETB_Cubes_ Includes Threshold Optimization by Mahboubeh
#
# Calculate SIR and/or GRD analysis by year for selected subset areas. For example, running melt-onset-dates by year and pixel, or calculating intrapixel stddevs.
#
# Use this notebook for any analysis/display that is examining the TBs from the cubefiles.
#
# Saves MOD/EHD DAV booleans with geolocation information in pickle files that can be examined/displayed elsewhere.
#
# Makes geotiff maps of various annual and/or average results.

# %% [markdown]
# ## Load in all the modules needed
#
# ### Required Additional Libraries for Threshold Optimization
#
# This block includes additional libraries that may not be installed in your cetb environment.
# To ensure smooth execution, install the following dependencies before running the code.
#
# 1) Use the following command if using pip:
#
# **pip install gdal geopandas rasterio shapely scipy**
#
#
# 2) Or if using conda:
#
# **conda install -c conda-forge gdal geopandas rasterio shapely scipy**

# %%
# %matplotlib inline
# check if a windows machine, it needs special attention
# this extra step will bypass an error from mpl_toolkits.basemap
import os
if os.name == 'nt':
    os.environ["PROJ_LIB"] = os.path.join(os.environ["CONDA_PREFIX"], "Library", "share")
    os.environ["GDAL_DATA"] = os.path.join(os.environ["CONDA_PREFIX"], "Library", "share", "gdal")
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from netCDF4 import Dataset, num2date
import numpy as np
import pandas as pd
from pathlib import Path
import re
from cetbtools.ease2conv import Ease2Transform
from mpl_toolkits.basemap import Basemap
import glob
from pathlib import Path
from osgeo import gdal
import geopandas as gpd
import rasterio
from shapely.geometry import Point
from scipy.signal import argrelextrema, gaussian, find_peaks
import csv
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# # Set parameters to display more than default rows/cols in Data frames

# %%
pd.set_option('display.max_rows', 999)
pd.set_option('display.min_rows', 200)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 120)
pd.set_option('display.max_colwidth', 10)

# %% [markdown]
# ### Each user needs to create a new directory for Threshold Optimization, named ThresholdDir.

# %%
# Define the local machine location of CETB data cubes
# This directory is expected to contain subdirectories in the following hierarchy
# that duplicates the hierarchy on the Google Shared Drive NSIDC-SD-CETB/v1/, 
# for example:
# dataDir/F13_SSMI/N/nc_cubes/cubes_<regionName>
user = 'Mahboubeh' #Mariah #MJWindows #MAHMac
if ('Joan' == user):
    dataDir = Path(Path.home(), 'ceph', 'jmr204group','CETB_cubes')
    #dataDir = '/mnt/data3/cetb/nsidc0630_v1/' #jmr machine fringe 
    scriptDir = Path(Path.home(), 'ipynb_melt_onset', 'scripts')
    outDir = Path(Path.home(), 'cetb/ipynb_melt__onset_plots')
elif ('Mariah' == user):
    dataDir = Path(Path.home(), 'nsidc0630_v1') # Mariah's PC or Mary Jo's Mac
    scriptDir = Path(Path.home(), 'ipynb_melt_onset', 'scripts')
    outDir = Path(Path.home(), 'nsidc0630_v1', 'MODs')
elif ('MJWindows' == user):
    dataDir = Path('Z:/mj On My Mac/nsidc0630_v1') # Mary Jo's Windows machine
    scriptDir = Path(Path.home(), 'ipynb_melt_onset', 'scripts')
    outDir = ''
elif ('MJMac' == user):
    dataDir = Path(Path.home(), 'nsidc0630_v1') # Mary Jo's Mac
    scriptDir = Path(Path.home(), 'ipynb_melt_onset', 'scripts')  
    outDir = Path(Path.home(), 'nsidc0630_v1', 'pkls')
elif ('MAHMac' == user):
    dataDir = Path(Path.home(), 'nsidc0630_v1') # Molly's Mac
    scriptDir = Path(Path.home(), 'Projects', 'ipynb_melt_onset', 'scripts')  
    outDir = Path(Path.home(), 'nsidc0630_v1', 'pkls')
elif ('Mahboubeh' == user):
    dataDir = '/home/mabb21/ceph/jmr204group/CETB_cubes' # Mahboubeh's Windows machine
    scriptDir ='/home/mabb21/ipynb_melt_onset/scripts'
    outDir = '/home/mabb21/ipynb_melt_onset_plots'
    ThresholdDir = '/home/mabb21/OptimizedThresholds'
    if not os.path.isdir(ThresholdDir):
        os.makedirs(ThresholdDir)
else:
    raise ValueError("unknown user= %s\n" % (user) )
    
# %cd $scriptDir
dataDir, outDir, ThresholdDir, user
# Out:
# /home/mabb21/ipynb_melt_onset/scripts
# ('/home/mabb21/ceph/jmr204group/CETB_cubes',
#  '/home/mabb21/ipynb_melt_onset_plots',
#  '/home/mabb21/OptimizedThresholds',
#  'Mahboubeh')

# %% [markdown]
# # Newly Added Imports for Threshold Optimization and CETB SSD melt analysis
#
# New imports in this script are marked with **`#Newly added`** in front of them.

# %%
# load the custom functions
from CETB_IO import read_Tb_whole
from CETB_IO import coords
from CETB_algorithmsMB import calc_DAV
from CETB_IO import grid_locations_of_subset
from CETB_IO import years_for
from CETB_IO import get_sir_info
from CETB_IO import write_df_to_geotiff
from CETB_IO import get_site_boundaries
from CETB_algorithmsMB import DAV_MOD
from CETB_analysis import MOD_array
from CETB_algorithmsMB import extract_relevant_data, compute_smoothed_histogram, plot_histogram, analyze_histogram  #Newly added
from CETB_IO import read_Tb_std_dev    #Newly added
from CETB_IO import find_cube_offset    #Newly added 
from CETB_analysis import BOX_array   #Newly added, I created BOX_array (and put that in the CETB_analysis) for region-based Threshold Optimization

# %% [markdown]
# ## Specify inputs
#
# This cell is the place to specify the cube name to analyze ('WesternCA', 'AKYukon', etc)
# and the sensor and channels to process.
#
# Here is the current map of coverages of our subset cubes for the Northern Hemisphere:
#
# <img src='graphics/CETB_EASE2_N_cubes_geolocations.v2.png' width="800" height="800">

# %%
#Specify region, satellite, sensor, channel, and image reconstruction algorithm of interest in file name
# this notebook will read in 2 CETB datasets so that channels/algorithms/sensors can be compared
region='AKYukon' #'AKYukon' #'Laptev' #'WesternCA'  #'GLaIL'  #make this the same syntax as cubefilenames and sub-directory
sat_GRD='F13'   #'AQUA' for AMSRE, 'F13','F14','F15'... for SSMI 'F18' 'GCOMW1
sat_SIR= 'F13'
sensor_GRD='SSMI'  #'AMSRE', 'SSMI', SSMIS, etc. AMSR2
sensor_SIR='SSMI'
channel_GRD='37V'  #'36V','36H', '18V','18H', etc. '19V','19H' and '37V','37H' for SSMI)
channel_SIR='37V'
alg_GRD='GRD'   #SIR or GRD
alg_SIR='SIR'

hemName = 'N' 

# get sir to grd factor and sir_gpd name
sir_2_grd_factor, sir_gpd = get_sir_info(channel_SIR, hem=hemName)
print("channel=%s, sir_2_grd_factor=%d, sir_gpd=%s" % (
    channel_SIR, sir_2_grd_factor, sir_gpd))

cubeType_GRD = channel_GRD + '-' + alg_GRD
cubeType_SIR = channel_SIR + '-' + alg_SIR
  
if ('SSMI' == sensor_GRD) or ('SSMIS' == sensor_GRD):
    provider='CSU' 
    version='v1.*'
elif 'AMSRE' == sensor_GRD:
    provider='RSS'
    version='v1.3'
elif 'AMSR2' == sensor_GRD:
    provider='PPS_XCAL'
    version='v1.*'
    
# on Joan's machine
#datadir_GRD = dataDir + sat_GRD+'_'+sensor_GRD+'/'+region+'/' 
#datadir_SIR = dataDir + sat_SIR+'_'+sensor_SIR+'/'+region+'/' 
# on MJ's machine
datadir_GRD = "%s/%s_%s/%s/nc_cubes/cubes_%s/" % (
    dataDir, sat_GRD, sensor_GRD, hemName, region )
datadir_SIR = "%s/%s_%s/%s/nc_cubes/cubes_%s/" % (
    dataDir, sat_SIR, sensor_SIR, hemName, region )

# prefix filepath
prefix_GRD = 'CETB.cubefile.'+region+'.'+sat_GRD+'_'+sensor_GRD+'-'+channel_GRD+'-'+alg_GRD+'-'+provider+'-'+version
prefix_SIR = 'CETB.cubefile.'+region+'.'+sat_SIR+'_'+sensor_SIR+'-'+channel_SIR+'-'+alg_SIR+'-'+provider+'-'+version

Years=years_for(sat_GRD)
#might want to truncate Years to subset if very slow during testing
#if we give it more years than available what do we want it to do? 
#warn me but return what it finds

# Only truncate Years here for speed and/or testing
subYears = Years[7:10] 
#subYears = Years
# Out:
# channel=37V, sir_2_grd_factor=8, sir_gpd=EASE2_N3.125km

# %%
subYears
# Out:
# [2002, 2003, 2004]

# %%
get_site_boundaries('')
# Out:
# Invalid SiteLabel - valid values are
#                      NEUkraine lat:   51.0500,  51.0500 lon:   34.5000,  34.5000  NE, Ukraine
#              ChernihivForested lat:   51.9078,  51.9078 lon:   31.2956,  31.2956  Chernihiv Oblast Forested, Ukraine
#                    ChernihivAg lat:   51.6987,  51.6987 lon:   31.4491,  31.4491  Chernihiv Oblast Agricultural, Ukraine
#                  KomsomoletsIs lat:   80.5167,  80.5167 lon:   94.8167,  94.8167  Komsomolets Is., Severnaya Zemlya AWS, Russia
#                        Alberta lat:   49.7300,  49.7300 lon: -111.1400,-111.1400  Low Relief Test, Alberta
#                     GreatLakes lat:   47.3531,  47.3531 lon:  -89.8613, -89.8613  Great Lakes Test Site, Lake Superior E of Duluth
#             Barrow3kmSEAirport lat:   71.2709,  71.2709 lon: -156.6940,-156.6940  Barrow SE, AK
#             Barrow airport, AK lat:   71.2818,  71.2818 lon: -156.7720,-156.7720  BarrowAirport
# ...

# %% [markdown]
# ## Specify the geographic bounds of the subset area inside the cube to process
#
# Also set the 'Site' name for identifying output files.

# %%
SiteLabel='SNOTEL1'
lat_start, lat_end, lon_start, lon_end, Site=get_site_boundaries(SiteLabel)
lat_start, lat_end, lon_start, lon_end, Site
# Out:
# (65.07833, 65.07833, -145.87067, -145.87067, 'Monument Creek, AK')

# %%
dataDir, datadir_GRD, prefix_GRD
# Out:
# ('/home/mabb21/ceph/jmr204group/CETB_cubes',
#  '/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/',
#  'CETB.cubefile.AKYukon.F13_SSMI-37V-GRD-CSU-v1.*')

# %%
# get the GRD pixel IDs for the lat/lon rectangle chosen
# and then calculate the corrsponding SIR pixel row/col numbers
rows_cols_GRD=coords(datadir_GRD, prefix_GRD, lat_start, lat_end, lon_start, lon_end)
rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)
print(rows_cols_GRD)
print(rows_cols_env)
# Out:
# (44, 45, 40, 41)
# (352, 360, 320, 328)

# %%
# load GRD Tb data
data_GRD = read_Tb_whole(datadir_GRD, prefix_GRD, subYears,
                         rows_cols_GRD[0], rows_cols_GRD[1], rows_cols_GRD[2], rows_cols_GRD[3])

# load in SIR TB data
data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, subYears,
                         rows_cols_env[0], rows_cols_env[1], rows_cols_env[2], rows_cols_env[3])
# Out:
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-GRD-CSU-v1.3.2002.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-GRD-CSU-v1.3.2003.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-GRD-CSU-v1.3.2004.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2002.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2003.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2004.TB.nc...

# %%
# calculate DAV for the Tb data that was imported
DAV_GRD = calc_DAV(data_GRD['TB'])
DAV_SIR = calc_DAV(data_SIR['TB'])

# %%
# Examine shapes of the dataFrames and the DAV (masked arrays)--these are (timeSteps, rows, cols)
data_SIR['TB'].shape, DAV_SIR.shape, data_GRD['TB'].shape, DAV_GRD.shape
# Out:
# ((2192, 8, 8), (2192, 8, 8), (2192, 1, 1), (2192, 1, 1))

# %% [markdown]
# ## TODO: Placeholder here to calculate the std dev of the 64 SIR pixels in each GRD pixel
# ## Will also need to decide how to save this additional information

# %% [markdown]
# ## Specify the MOD and EHD parameters
#
# window : window for MOD algorithm, '10' would be 5 days (remember that the CETB data come in 2 measurements per day)
#
# count : number of Tb/DAV exceedances needed to trigger melt-onset-date
#
# DAV and TB thresholds here are from these publications:
#
# Johnson et al 2020 AMSRE rSIR Tb >= 249 DAV>=13 and AMSRE GRD Tb>=243 DAV>=14
#
# From Johnson et al 2020 SSMI rSIR and GRD Tb>=247 DAV>=10
#
# DAV_threshold : diurnal amplitude variation in Kelvins default is 10 (per pubs)
# Tb_threshold : TB threshold above which melt is possibly triggered
#
# Colorado (Johnson et al 2020) used 5 times in 7 day window
# Patagonia (Monahan and Ramage 2010) and Yukon (Semmens et al 2013?) used 3 times in 5 day window

# %%
# From Matias Fall 2022 forward facing indexer to assign rolling sum value to the beginning of window
# Setting the window_size sets the number of observations,'14' would be 7 days (2 measurements per day)
# If you don't want to use the forward facing indexer, then change "window" to a numeral, this will assign
# the rolling sum value to the end of the window
MOD_window = 10
MOD_count = 3
indexer = pd.api.indexers.FixedForwardWindowIndexer(window_size=MOD_window)
window = indexer   # this assigns the rolling sum value to the beginning of the window
#window = MOD_window # this assigns the rolling sum value to the end of the window

# Number of Tb/DAV exceedances to trigger EHD = end of high DAV
# At the current time, EHD is not using the forward facing indexer, using default behavior
# From Matias Fall 2022
# Theoretically you could do the same thing with the EDH_window here, but I'm not sure
# you would ever want that
EHD_window = 20 
EHD_count = 7 

# number of Tb/DAV exceedances to trigger MOD
#From Johnson et al 2020 AMSRE rSIR Tb >= 249 DAV>=13 and AMSRE GRD Tb>=243 DAV>=14
#From Johnson et al 2020 SSMI rSIR and GRD Tb>=247 DAV>=10
DAV_threshold = 10
Tb_threshold = 246

# %%
# generate histogram - SIR - all data
# This histogram will include all points that are in the CETB_SIR array
year=2003

#data = CETB_SIR[cal_year==year]
data = data_SIR['TB'][data_SIR['cal_year']==year, :, :] # SIR data for all pixels in this year
data = data[data>=0]
bins = range(150, 300)  # bins for histogram
fig,ax = plt.subplots()
ax.hist(data, bins)
ax.set_title('TB SIR Histogram, area=%s, year=%s' % (Site, str(year)))
ax.axvline(x=Tb_threshold, color='red')
ax.set_xlabel('Brightness Temp (K)')

# %% [markdown]
# ---
#
# #### After examining the position of the legacy Tb threshold on the histogram in code block 15: From here, we will have the Tb & DAV Thresholds Optimization Algorithms
# *By Mahboubeh Boueshagh, PhD Candidate, Lehigh University*
#
#
# ### Purpose:
# This algorithm determines optimized Tb and DAV thresholds for snowmelt detection using satellite data. It improves upon the legacy 246K Tb threshold and 10K DAV threshold by performing site-specific histogram and time series analysis and considering regional snowmelt characteristics. This methodology ensures that the thresholds are dynamically adapted to each region based on site-specific data, leading to better accuracy in snowmelt onset detection compared to using a fixed threshold (e.g., Tb = 246K and DAV = 10K).
#
#
# ### Applications & Importance:
# - Enhances the accuracy of snowmelt detection by dynamically adapting thresholds for different sites.
# - Accounts for regional climate differences in snow behavior.
# - Reduces false detections by excluding non-relevant data periods for Tb threshold algorithm and by filtering irrelevant seasonal variations for DAV threshold algorithm.
# - Provides a visually interpretable method for validating DAV-based melt detection.
# - Can be extended to other regions where DAV is a key snowmelt indicator using satellite-derived Tb data.
#
#
# ### Overview:
# This section includes two parts:
#
# 1️⃣ **Running the Tb and DAV algorithm for a single site of interest in a specific year.**
#    - The site is selected in **code block 8**.
#    - Example: *Monument Creek* (SiteLabel = `'SNOTEL1'`) in *Alaska*.
#
# 2️⃣ **Running the Tb and DAV algorithm for a region of interest.**
#    - This is done by extracting the **rSIR pixels** located within the selected region for a specific year.
#    - The site is selected in **code block 19**.
#    - Example: *Box of Interest, AK* (SiteLabel = `'AalaskaRegion'`) in *Alaska*.

# %% [markdown]
# ---
# ---
#
# Part 1️⃣ **Running the Tb and DAV algorithm for a single site of interest in a specific year.**
#
# ---
# ---

# %% [markdown]
# ### Brightness Temperature (Tb) Threshold Optimization Algorithm for Snowmelt Detection
#
# ### Key Features:
# 1. Handles Different Snow Classes:
#    - Optimizes thresholds based on the local climate and snowmelt dynamics.
#    - Snow classes are processed differently to focus on their distinct melt periods.
#    - For Snow Classes: ['Boreal Forest', 'Montane Forest', 'Tundra', 'Prairie'] >> Time Frame: January to September >>> For regions where snow is a defining feature of the landscape and climate, capturing the entirety of a snow and melt season within a single year is crucial. Empirical trials have shown that focusing on the January to September period allows for more insightful analysis of the snow and melt cycle. By excluding the months of October to December, the data analysis sharpens its focus on the active snowmelt period, reducing noise from the accumulation phase, which predominates in those months. Focusing on the critical snowmelt months from January to September allows for a better understanding of data variations due to environmental factors like temperature fluctuations and solar radiation, which significantly influence the melting processes. This period covers winter, spring, and part of summer, including the tail end of the Arctic winter, the entire spring thaw, and most of the summer melt season. As a result, the histograms generated during this time will primarily reflect the brightness temperatures associated with these conditions, showcasing a range of values from very cold (frozen conditions) to warmer (surface melting). By excluding October to December, the histograms will not capture the re-freezing period and the onset of the new snow season. This helps in emphasizing the melting phase, aiding in more precise identification of the onset of snowmelt.
#    - For Snow Classes: ['Maritime', 'Ephemeral', 'Ice', 'Ocean'] >> Time Frame: Calendar Year (January to December) >>> For regions where snow is not the primary climatic feature or where it is less predictable, using the full calendar year (January to December) provides a consistent and straightforward timeframe for analysis. In these areas, where transient or less defining snow events occur, capturing long-term trends can be more beneficial than focusing solely on specific snowmelt periods.
#    - Characteristics of Different Snow Classes:
#      1) Tundra: Long, harsh winters and short summers, requiring a focused analysis on the snowmelt period.
#      2) Boreal Forest: Dominated by long, cold winters, where snow remains a significant factor for much of the year.
#      3) Montane Forest: Diverse snow conditions due to varied elevations and aspects, making it important to study the snow season in its entirety.
#      4) Prairie: Experiences unpredictable snow events; capturing the entire snow cycle from the first snowfall to complete melt is crucial.
#      5) Maritime: Milder climates with more transient snow events, benefiting from a broader analysis over the calendar year.
#      6) Ephemeral: Sporadic snowfall that does not last long, making it suitable to consider the entire year.
#      7) Ice: Persistent ice cover throughout the year, with long-term trends often more relevant than seasonal changes.
#      8) Ocean: No defined snow season, where ice and snow accumulation are best analyzed over the calendar year due to their long-term implications for climate change.
#     - Snow classes are derived from Global Seasonal-Snow Classification, Version >>> Liston, G. E. & Sturm, M. (2021). Global Seasonal-Snow Classification. (NSIDC-0768, Version 1). [Data Set]. Boulder, Colorado USA. NASA National Snow and Ice Data Center Distributed Active Archive Center. https://doi.org/10.5067/99FTCYYYLAQ0. [describe subset used if applicable]. Date Accessed 02-27-2025.
#
# 2. Applies Data Filtering & Processing Steps:
#    - Uses specific time frames to exclude irrelevant data and focus on snowmelt phases.
#    - Performs histogram smoothing and peak detection to identify key temperature transitions.
#
# 3. Enhances Snowmelt Detection Accuracy:
#    - Removes physically impossible measurements.
#    - Uses adaptive threshold detection for different snow classes.
#    - Identifies peak transition points in the brightness temperature distribution.
#
# ---
#
# ### Methodology & Workflow for Tb Threshold Optimization Algorithm
# #### Step 1: Extract Brightness Temperature Data (Based on Snow Class)
# - The algorithm reads satellite brightness temperature (Tb) data and selects the relevant time period
#   based on the snow classification of the region.
# - For Boreal Forest, Montane Forest, Tundra, and Prairie:
#   - Only data from January to September is used to avoid noise from the snow accumulation period.
#   - This ensures the histogram primarily reflects melting phases.
# - For Maritime, Ephemeral, Ice, and Ocean:
#   - The full calendar year (January to December) is used.
#   - This is because snowmelt in these regions is less predictable or persists year-round.
#
# #### Step 2: Compute a Smoothed Histogram of Brightness Temperature
# - A histogram is generated from the filtered Tb data.
# - Smoothing is applied using a Gaussian kernel to highlight significant temperature transitions.
# - The optimal kernel width is computed using Silverman’s rule, adjusted for this application.
# - This allows better identification of peaks and valleys in the temperature distribution.
#
# #### Step 3: Detect Temperature Thresholds for Snowmelt
# - Peak detection is performed to find key temperature transitions.
# - The 70th percentile of histogram values is used as a threshold to detect prominent peaks.
# - A distance parameter (determined via empirical testing) helps separate meaningful peaks.
#
#
# #### Step 4: Determine the Optimal Threshold Temperature
# - If two peaks (bimodal distribution) are found, the minimum point between them is selected as the threshold.
# - If one peak (unimodal distribution) is found, a warning is issued, and manual review is needed.
# - If more than two peaks are found, an additional filtering step refines peak selection:
#   - Peaks are re-selected based on a mean-based threshold, defined as the mean of the histogram.
#   - Only peaks with a prominence exceeding the mean of the histogram are retained, eliminating minor fluctuations or noise.
#   - If more than three peaks remain after filtering, the histogram is flagged as complex and may require manual review.
#   - If exactly three prominent peaks remain, the optimal threshold is determined as the minimum valley point between the two most significant peaks.
#
#
# #### Step 5: Generate and Save Results
# - A histogram plot is generated, displaying:
#   - The smoothed brightness temperature distribution
#   - The new optimized Tb threshold (dashed black line)
#   - The legacy 246K threshold (dashed red line) for comparison
# - The detected Tb threshold is saved for each site.
#
# ---

# %% [markdown]
# ### Data preparation for single-site analysis of Tb algorithm:
# Extracts the snow class for the site and makes a dataframe for it, which includes Site, lat_start, lon_start, Snow_Class_Code, SnowClasses

# %%
### This block creates a dataframe, including necessary columns, Cont'd...
### (including, Site, lat_start, lon_start,	Snow_Class_Code, SnowClasses) for the site of interest to be used in the Tb threshold algorithm.
### You will need to put the SnowClass1km.tif in a directory in your local machine for snow classification.

# Define the snow class categories based on Global Seasonal-Snow Classification, Version 1. 
categories = {
    1: 'Tundra',
    2: 'Boreal Forest',
    3: 'Maritime',
    4: 'Ephemeral',
    5: 'Prairie',
    6: 'Montane Forest',
    7: 'Ice',
    8: 'Ocean'
}


# Create a GeoDataFrame using the lat and long variables
geometry = [Point(lon_start, lat_start)]
gdf = gpd.GeoDataFrame(geometry=geometry, columns=['geometry'])
gdf['Site'] = SiteLabel
gdf['lat_start'] = lat_start
gdf['lon_start'] = lon_start

# Open a raster file (GeoTIFF) representing snow classes using rasterio and extract the snow class for the site.
# Remember: You will need to put the SnowClass1km.tif in a directory in your local machine for snow classification.
with rasterio.open('/home/mabb21/Research/SnowClass1km.tif') as src:
    # Read the first band of the raster file
    image = src.read(1)
    # Extract the affine transform object to convert geographic coordinates to pixel coordinates
    transform = src.transform

    # Extract pixel values for each site from the raster
    # The conversion from geographic coordinates to pixel coordinates is done using the transform
    gdf['Snow_Class_Code'] = [
        image[
            np.round((lat - transform.f) / transform.e).astype(int),
            np.round((lon - transform.c) / transform.a).astype(int)
        ]
        for lat, lon in zip(gdf['lat_start'], gdf['lon_start'])
    ]

# Map the extracted snow class codes to their category names (Defined at the top of this block)
gdf['SnowClasses'] = gdf['Snow_Class_Code'].map(categories)

# Convert the GeoDataFrame back into a regular pandas DataFrame
Prepared_df = pd.DataFrame(gdf)
# Drop the 'geometry' column from the DataFrame as it's not needed anymore
Prepared_df.drop('geometry', axis=1, inplace=True)
Prepared_df

# %% [markdown]
# ### Run the Tb algorithm for single-site optimization:
#
# This code calls different functions from CETB_algorithms script, including, extract_relevant_data, compute_smoothed_histogram, plot_histogram, analyze_histogram. The output shows the processing site and its snow class, the type of detected distribution, values of located dominant peaks, and a plot showing the new optimized Tb threshold.
#
# ##### Function Explanations:
#
# 1️⃣ extract_relevant_data:
# This function filters Tb data based on the snow class and selected year. It extracts data from January to September for specific snow classes (e.g., Boreal Forest, Tundra) and the full calendar year for others. It also removes physically impossible values to ensure data quality.
#
# 2️⃣ compute_smoothed_histogram:
# This function creates a histogram of the brightness temperature data and applies smoothing using a Gaussian kernel. It determines the optimal kernel width using Silverman’s rule and ensures proper visualization of the Tb distribution. The smoothed histogram helps in detecting peaks and valleys for threshold determination.
#
# 3️⃣ analyze_histogram:
# This function identifies Tb thresholds by detecting peaks in the smoothed histogram. If two peaks are found, it selects the minimum valley as the threshold, while for complex histograms, it applies additional filtering to find the histograms with three peaks. The computed threshold is then used for snowmelt detection.
#
# 4️⃣ plot_histogram:
# This function visualizes the Tb histogram, including the smoothed curve, detected peaks, and Tb threshold. It highlights the legacy (246K) and optimized thresholds and saves the plot as a PNG file. If only one peak is found, it issues a manual review warning.

# %%
### This block is the Tb threshold algorithm that estimates thresholds for a site (rSIR pixel) in a single year!

snow_class = Prepared_df['SnowClasses'].iloc[0]
print(f"Processing site: {Site}, Snow Class: {snow_class}")

# Year of interest 
year = [2003]
        
# Calculate the row and column coordinates of the GRD pixels corresponding to the site's lat and lon
rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_start, lon_start, lon_start)
        
# Calculate the envelope of coordinates for 64 SIR pixels
rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)
        
# Read brightness temperature data for the calculated coordinates from the SIR dataset
data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, year, rows_cols_env[0], rows_cols_env[1], rows_cols_env[2], rows_cols_env[3])

# Extract relevant data from data_SIR
cal_year = data_SIR['cal_year']
cal_month = data_SIR['cal_month']
        
# Filter the data based on criteria like snow class and year
data = extract_relevant_data(data_SIR, year, cal_year, cal_month, snow_class, Site)
        
# Calculate a smoothed histogram for the brightness temperature data
hist, bin_edges, hist_smooth = compute_smoothed_histogram(data, snow_class, Site)
        
# Analyze the histogram to derive results: Tb thresholds
results = analyze_histogram(hist, bin_edges, hist_smooth, Site, year, sensor_SIR, channel_SIR, snow_class, ThresholdDir)


# Print the calculated Tb Threshold   
print(f"Tb Threshold for {Site}, Snow Class {snow_class}, Year {year[0]}: {results['threshold']}K")

# %% [markdown]
# ### DAV (Diurnal Amplitude Variations) Threshold Optimization Algorithm for Snowmelt Detection: Run the DAV algorithm for single-site optimization >>> The output shows the processing site, DAV Threshold (90th Percentile), DAV Threshold (95th Percentile), and DAV Threshold (Average of 90th and 95th percentile)

# %% [markdown]
# Author: Mahboubeh Boueshagh
#
# This algorithm determines optimized DAV thresholds to detect the onset of snowmelt using CETB data. The 90th percentile of DAV is used as the threshold after validating that the DAV distribution is right-skewed, meaning most values are low, with occasional high spikes representing snowmelt events.
#
# ### Key Features:
# 1. Extracts DAV Data for a Specific Site and Year
#    - Uses CETB data to calculate DAV.
#    - Filters data for the year of interest and removes noise.
#
# 2. Calculates Percentile-Based Thresholds
#    - Computes the 90th and 95th percentiles of DAV to capture extreme variations.
#    - Uses the 90th percentile as the final DAV threshold, since testing showed it captures sudden increases in DAV and aligns with snowmelt onset while providing similar results to the 95th percentile without being overly restrictive.
#
# 3. Visualizes DAV and Thresholds
#    - Plots DAV time series with 90% and 95% thresholds as reference lines.
#    - Saves the plot for further analysis and verification.
#
#
# ### Why Use the Percentile Method for Melt Detection?
# - The DAV distribution is right-skewed, meaning most values are small, but there are occasional large spikes.
# - These spikes represent sudden increases in DAV, which typically occur when snow begins to melt.
# - If a normal distribution were used, the threshold would be influenced by the mean, which is affected by
#   the many low DAV values, leading to an unreliable threshold.
# - By using the percentile method, we focus on the extreme values rather than the mean, which helps
#   isolate the melt signal from typical background variations.
# - The 90th percentile was chosen because it effectively captures these spikes while avoiding false detections from smaller fluctuations. Additionally, testing showed that using the 90th percentile produces results similar to the 95th percentile without significantly altering melt detection.
#
# ### Note from tested techniques:
# In the first try to optimize DAV algorithm that works best for a range of sites, I used the rate of change of DAV and its mean and std values to estimate the DAV threshold when it starts to increase during the melting season. I decided to do more analysis, and I made some adjustments to the algorithm. I checked the distribution of DAV and its rate of change. The DAV has a right-skewed distribution and its rate of change has a relatively normal distribution (look at the below chunk of code). When the DAV distribution is right-skewed, it means that there are more frequent smaller values with occasional larger spikes. With a longer tail on the right side, the majority of the data points will cluster on the lower end (representing typical non-melt days), while occasional higher spikes would indicate unique events, potentially snowmelt events. Thus, I decided to use the percentile method for melt detection. I tested the 90th and 95th percentiles, and after trial and error, and validation, I chose the 90th percentile as the DAV threshold for each site. However, the choice of the threshold depends on how conservative we want to be for melt detection.
#
#
# ### Important not about the next block of code for DAV:
#
# It's important to have at least two years in 'subYears' to avoid certain errors, including the year of interest and the year after, for example, for 2003, you should also include 2004 in subYears.
#
# ---

# %%
### This block is the optimized DAV algorithm for the site and year of interest!

# Subset of years
# It's important to have at least two years in 'subYears' to avoid certain errors, including the year of interest and the year after, Cont'd...
# for example, for 2003, you should also include 2004. 

subYears = Years[8:11] 

# Set the year of interest
year = 2003

# Function to extract and plot Tb and DAV for the specified year
def TbYear(CETB_data, DAV, cal_date, cal_year, year):
    """
    Extracts the time-series of Tb and DAV for the given year.
    
    Parameters:
        CETB_data: The CETB data array (brightness temperature data).
        DAV: The DAV data array (Diurnal Amplitude Variations Melt Algorithm).
        cal_date: Array of datetime objects corresponding to the CETB data.
        cal_year: Array of years corresponding to the CETB data.
        year: The year of interest to filter data.

    Returns:
        DataFrame containing the DAV data for the specified year and site.
    """
    # Create a list of pixel indices for the y and x dimensions
    y_dims_list = list(range(len(CETB_data[0, :, 0])))  # y-dimension pixel indices
    x_dims_list = list(range(len(CETB_data[0, 0, :])))  # x-dimension pixel indices

    # Boolean mask to filter data for the year of interest
    thisYr = cal_year == year

    # Iterate over all y and x pixel indices to plot the time series (if needed)
    for i in y_dims_list:
        for j in x_dims_list:
            # Create DataFrames for DAV time series for the selected year
            DAV_df = pd.DataFrame(DAV[thisYr, i, j], index=cal_date[thisYr])

    # Return the final DataFrame containing DAV for the specified year
    return DAV_df


# Print a message indicating which site is being processed
print(f"Processing site: {Site}")

# Calculate the row and column coordinates of the GRD pixels corresponding to the site's lat and lon
rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_start, lon_start, lon_start)
        
# Calculate the envelope of coordinates for 64 SIR pixels
rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)
        
# Read brightness temperature data for the calculated coordinates from the SIR dataset
data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, subYears, rows_cols_env[0], rows_cols_env[1], rows_cols_env[2], rows_cols_env[3])

# Step 1: Calculate DAV using an existing function (assumed to be implemented elsewhere)
DAV_SIR = calc_DAV(data_SIR['TB'])  # DAV is calculated based on TB (brightness temperature) data


# Step 2: Extract the Tb and DAV data for the specified year
DAV_df = TbYear(data_SIR['TB'], DAV_SIR, data_SIR['cal_date'], data_SIR['cal_year'], year)

# Step 3: Rename the DataFrame column to 'DAV' for clarity
DAV_df.columns = ['DAV']

# Step 4: Calculate the 90th and 95th percentiles of DAV values
DAV_threshold_Percentile90 = DAV_df['DAV'].quantile(0.90)  # 90% threshold
DAV_threshold_Percentile95 = DAV_df['DAV'].quantile(0.95)  # 95% threshold
DAV_Average = np.mean([DAV_threshold_Percentile90, DAV_threshold_Percentile95])

# Step 5: Print the DAV thresholds for the sitDAV_threshold_Percentile95)e and year of interest
print(f"DAV Threshold (90% Percentile) at {Site}, Year {year}: {DAV_threshold_Percentile90:.2f} K, Site: {Site}")
print(f"DAV Threshold (95% Percentile) at {Site}, Year {year}: {DAV_threshold_Percentile95:.2f} K, Site: {Site}")
print(f"DAV Threshold (Average) at {Site}, Year {year}: {DAV_Average:.2f} K, Site: {Site}")


# Step 6: Define the path to save the plot
save_path = os.path.join(ThresholdDir, f"{Site}_{year}_{sensor_SIR}DAVplot.png")

# Step 7: Plot the DAV time series with 90% and 95% thresholds
plt.figure(figsize=(12, 7))  # Set figure size
plt.plot(DAV_df.index, DAV_df['DAV'], label='DAV', linewidth=1.5)  # Plot DAV values over time

# Add horizontal lines for the 90% and 95% percentile thresholds
plt.axhline(y=DAV_threshold_Percentile90, color='blue', linestyle='--', 
            label=f'DAV Threshold (90% Percentile): {DAV_threshold_Percentile90:.2f} K', linewidth=2.5)
plt.axhline(y=DAV_threshold_Percentile95, color='red', linestyle='--', 
            label=f'DAV Threshold (95% Percentile): {DAV_threshold_Percentile95:.2f} K', linewidth=2.5)
plt.axhline(y=DAV_Average, color='black', linestyle='--', 
            label=f'DAV Threshold (Average of 90% and 95% Percentiles): {DAV_Average:.2f} K', linewidth=2.5)

# Set plot labels and title
plt.xlabel('Time')  # X-axis label
plt.ylabel('DAV (K)')  # Y-axis label
plt.title(f'DAV Thresholding using 90% and 95% Percentiles & Average of Percentiles, {Site}, {year}')  # Plot title

# Add legend and set its position
plt.legend(loc='upper right')

# Adjust y-axis limits to fit the data with some padding
plt.ylim([min(DAV_df['DAV']) - 5, max(DAV_df['DAV']) + 5])

# Save the plot to the specified path
plt.savefig(save_path)

# Display the plot
plt.show()

# %% [markdown]
# ---
# ---
#
# Part 2️⃣ **Running the Tb and DAV algorithm for a region of interest.**
#
# ---
# ---

# %% [markdown]
# ## From here: Tb Threshold Optimization Algorithm for running within a bounding box of interest! For example, AlaskaRegion (below) in AK!

# %% [markdown]
# First select your region as: SiteLabel='AalaskaRegion'

# %%
### The SiteLabel need to be a bounding box, you can add yours to the CETB_IO script. 
SiteLabel='AalaskaRegion'
lat_start, lat_end, lon_start, lon_end, Site=get_site_boundaries(SiteLabel)
lat_start, lat_end, lon_start, lon_end, Site
# Out:
# (63, 65, -143, -142, 'Box of Interest, AK')

# %% [markdown]
# Then, we need to extract those rSIR pixels located in the bounding box: This block produces a dataframe of pixels with these columns >> Site, lat_start, lon_start, x, y
#
# Note that BOX_array in the next block is a new function in CETB_analysis used to extract lat and long coordinates within the bounding box.

# %%
### This block extracts the latitude and longitude coordinates for a bounding box of interest when running the code for a specific region.

# Specify the year to get the coordinates
year = [2003]

# Define margin (in degrees) to ensure all pixels are included within the bounding box
bounding_box_margin = 4  

# Compute dynamic bounding box based on min/max of lat_start and lon_start in site_data
lon_min = lon_start - bounding_box_margin
lon_max = lon_start + bounding_box_margin
lat_min = lat_start - bounding_box_margin
lat_max = lat_start + bounding_box_margin

# Get cube offset for finding row/col (region-specific function)
find_cube_offset(region, cubeDir=datadir_SIR, cubeType=cubeType_SIR, verbose=False)

# Get the GRD pixel IDs for the selected lat/lon range and calculate corresponding SIR pixel row/col numbers
rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_end, lon_start, lon_end)
rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)
print("Rows and Columns for Selected Region:", rows_cols_env)

# Read brightness temperature data for the specified coordinates from the SIR dataset
data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, year, 
                          rows_cols_env[0], rows_cols_env[1], 
                          rows_cols_env[2], rows_cols_env[3])
# load GRD Tb data
data_GRD = read_Tb_whole(datadir_GRD, prefix_GRD, year,
                         rows_cols_GRD[0], rows_cols_GRD[1], rows_cols_GRD[2], rows_cols_GRD[3])

# Extract geolocation information using the BOX_array function
Sites_df = BOX_array(data_SIR, rows_cols_env)

# Define output filename and directory
output_filename = "Box_SIR_lat_lon_coordinates.csv"

# Ensure the directory exists
os.makedirs(ThresholdDir, exist_ok=True)

# Create the full output path and save the extracted data
output_csv_path = os.path.join(ThresholdDir, output_filename)
Sites_df.to_csv(output_csv_path, index=False)

print(f"Extracted site coordinates saved to: {output_csv_path}")

Sites_df.head(5)
# Out:
# Reading offset information from cubeFile=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2008.TB.nc...
# Rows and Columns for Selected Region: (320, 392, 224, 288)
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2003.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-GRD-CSU-v1.3.2003.TB.nc...
# Extracted site coordinates saved to: /home/mabb21/OptimizedThresholds/Box_SIR_lat_lon_coordinates.csv
#       Site  lat_start  lon_start          x          y
# 0  320,224  62.609783 -142.37... -1848437.5  2398437.5
# 1  320,225  62.627389 -142.42... -1845312.5  2398437.5
# 2  320,226  62.644976 -142.47... -1842187.5  2398437.5
# 3  320,227  62.662544 -142.51... -1839062.5  2398437.5
# 4  320,228  62.680092 -142.56... -1835937.5  2398437.5

# %% [markdown]
# ### Data preparation for region-based analysis of Tb algorithm:
# Extracts the snow class for each site and creates a dataframe containing Site, lat_start, lon_start, Snow_Class_Code, and SnowClasses.
# Unlike the data preparation block for single-site analysis, this version uses a loop to process all pixels within the bounding box extracted in the previous block.

# %% [markdown]
# ### Brightness Temperature (Tb) Threshold Optimization Algorithm for Snowmelt Detection

# %%
### This block creates a dataframe of pixels in the bounding box extracted from the previous block, including necessary columns, Cont'd...
### (including, Site, lat_start, lon_start,	Snow_Class_Code, SnowClasses) to be used in the main Tb threshold algorithm.  
### You will need to put the SnowClass1km.tif in a directory in your local machine for snow classification.

# Define the snow class categories based on Global Seasonal-Snow Classification, Version 1. 
categories = {
    1: 'Tundra',
    2: 'Boreal Forest',
    3: 'Maritime',
    4: 'Ephemeral',
    5: 'Prairie',
    6: 'Montane Forest',
    7: 'Ice',
    8: 'Ocean'
}

# Load site data into a pandas DataFrame and drop columns that contain only NaN values
# You can also use Sites_df dataframe created in the previous block
site_data = pd.read_csv('/home/mabb21/OptimizedThresholds/Box_SIR_lat_lon_coordinates.csv').dropna(axis=1, how='all')

bounding_box = [lon_min, lat_min, lon_max, lat_max]

print(f"Bounding Box: {bounding_box}")

# Convert the DataFrame into a GeoDataFrame
# The geometry for each row is created from its 'lon_start' and 'lat_start' columns
gdf = gpd.GeoDataFrame(site_data, geometry=gpd.points_from_xy(site_data.lon_start, site_data.lat_start))

# Filter sites based on the bounding box
gdf = gdf.cx[bounding_box[0]:bounding_box[2], bounding_box[1]:bounding_box[3]]

# Open a raster file (GeoTIFF) representing snow classes using rasterio
with rasterio.open('/home/mabb21/Research/SnowClass1km.tif') as src:
    # Read the first band of the raster file
    image = src.read(1)
    # Extract the affine transform object to convert geographic coordinates to pixel coordinates
    transform = src.transform

    # Extract pixel values for each site from the raster
    # The conversion from geographic coordinates to pixel coordinates is done using the transform
    gdf['Snow_Class_Code'] = [
        image[
            np.round((lat - transform.f) / transform.e).astype(int),
            np.round((lon - transform.c) / transform.a).astype(int)
        ]
        for lat, lon in zip(gdf['lat_start'], gdf['lon_start'])
    ]

# Map the extracted snow class codes to their category names
gdf['SnowClasses'] = gdf['Snow_Class_Code'].map(categories)

# Convert the GeoDataFrame back into a regular pandas DataFrame
site_data_combined = pd.DataFrame(gdf)
# Drop the 'geometry' column from the DataFrame as it's not needed anymore
site_data_combined.drop('geometry', axis=1, inplace=True)
site_data_combined.shape

# %% [markdown]
# # Running the Tb Algorithm for Region-Based Optimization:
# The rules and methodology remain the same as those used for single-site analysis. The only difference is that this version uses a loop to process all pixels within the bounding box extracted in the previous block. Then, it saves the optimized thresholds as a CSV file in the ThresholdDir (saving directory), which includes these columns >> Site, Snow Class, Latitude, Longitude, x, y, Tb Threshold.
#
# ## Avoiding Redundant Processing of rSIR Pixels in Each GRD Pixel
# In this implementation, in order to have maximum data for histogram analysis we use the Tb data for all 64 pixels, which means it will repeat the same process with the same data for each rSIR pixel or site. To avoid this, we ensure that the Tb threshold computation is performed only once for each GRD pixel, even though multiple rSIR pixels exist within it. Instead of repeating the threshold calculation for every individual rSIR pixel, we implement an efficient caching mechanism using the dictionary `processed_GRD_pixels`. Please note that we can also run the process using Tb data relevant to the single rSIR pixel, but we may have data gaps or not a very continuous histogram. By using this method, we increase efficiency, reduce processing time, and ensure consistency in assigning Tb thresholds across all rSIR pixels within the same GRD pixel.
#
#
# ### How We Avoid Redundant Computation:
# 1. Identify Unique GRD Pixels
# 2. Check if the GRD Pixel is Already Processed
# 3. Compute Tb Threshold Only Once per GRD Pixel
#    - If a new GRD pixel is encountered, the script processes only one rSIR pixel within it.
# 4. Assign the Same Threshold to All rSIR Pixels in That GRD Pixel
#    - Once a threshold is computed for a GRD pixel, it is directly assigned to all its corresponding rSIR pixels without reprocessing.
#
# ### Why This Approach is Efficient?
# - Minimizes redundant computation → Each GRD pixel is processed only once, significantly reducing computational cost.
# - Faster execution → Instead of processing all rSIR pixels individually, the loop efficiently assigns precomputed values.
# - Memory optimization → Storing previously computed values in a dictionary prevents unnecessary function calls and data storage.

# %%
csv_filename = "thresholds2003_02.csv"

# List to store the calculated minimum temperatures (Tb threshold) for each site
min_temperatures = []

def main():
    processed_GRD_pixels = {}  # Dictionary to store calculated thresholds for each GRD pixel

    # Iterate over each site in the combined dataframe (holding site information from previous chunk)
    for index, row in site_data_combined.iterrows():
        Site = row['Site']
        lat_start = row['lat_start']
        lon_start = row['lon_start']
        x = row['x']
        y = row['y']
        snow_class = row['SnowClasses']
        
        # Compute the corresponding GRD pixel coordinates
        rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_start, lon_start, lon_start)
        grd_pixel_key = tuple(rows_cols_GRD)  # Unique identifier for each GRD pixel

        # If this GRD pixel has already been processed, assign the stored Tb threshold to all its rSIR pixels
        if grd_pixel_key in processed_GRD_pixels:
            tb_threshold = processed_GRD_pixels[grd_pixel_key]
            print(f"Assigning existing Tb threshold for Site {Site} in GRD {grd_pixel_key}: {tb_threshold}")
        else:
            # Process only one rSIR pixel within this GRD pixel
            print(f"Processing site: {Site}, Snow Class: {snow_class} for GRD {grd_pixel_key}")

            # Calculate the envelope of coordinates for 64 SIR pixels
            rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)

            # Read brightness temperature data for the calculated coordinates from the SIR dataset
            data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, subYears, 
                                     rows_cols_env[0], rows_cols_env[1], 
                                     rows_cols_env[2], rows_cols_env[3])

            # Year of interest
            year = [2003]

            # Extract relevant data from data_SIR
            cal_year = data_SIR['cal_year']
            cal_month = data_SIR['cal_month']

            # Filter the data based on criteria like snow class and year
            data = extract_relevant_data(data_SIR, year, cal_year, cal_month, snow_class, Site)

            # Calculate a smoothed histogram for the brightness temperature data
            hist, bin_edges, hist_smooth = compute_smoothed_histogram(data, snow_class, Site)

            # Analyze the histogram to derive results: Tb thresholds
            results = analyze_histogram(hist, bin_edges, hist_smooth, Site, year, sensor_SIR, channel_SIR, snow_class, ThresholdDir)

            # Store the calculated Tb threshold
            tb_threshold = results['threshold']
            processed_GRD_pixels[grd_pixel_key] = tb_threshold  # Save for reuse

        # Assign the Tb threshold value to all rSIR pixels located in this GRD pixel
        min_temperatures.append([Site, snow_class, lat_start, lon_start, x, y, tb_threshold])

    # Save the computed Tb thresholds to a CSV file
    csv_path = os.path.join(ThresholdDir, csv_filename)
    with open(csv_path, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Site', 'Snow Class', 'Latitude', 'Longitude', 'x', 'y', 'Tb Threshold'])
        writer.writerows(min_temperatures)

    print(f"CSV file saved with minimum temperature values: {csv_path}")

# Execute the main function
if __name__ == "__main__":
    main()

# %% [markdown]
# # Plot the Tb threshold map for the bounding box of interest! For exmaple, AalaskaRegion in AK.

# %% [markdown]
# ### Getting lat/lon of each pixel in the subset of 64, these will be used for plotting over basemap. We will use this block once for plotting both Tb and DAV threshold maps because the coordinates do not change for the Tb and DAV thresholds.

# %%
# Load the dataset containing the Tb thresholds, including latitude and longitude values. 
Thresholds = pd.read_csv(os.path.join(ThresholdDir, "thresholds2003_02.csv")).dropna(axis=1, how='all')  # Tb thresholds


# Extract latitude and longitude columns from the dataset
lat = Thresholds['Latitude']
lon = Thresholds['Longitude']

# Stack latitude and longitude values together into a single array
lat_lon = np.dstack((lat, lon))

# Reshape the stacked array into a 2D array where each row represents a pixel (lat, lon)
coordinates = lat_lon.reshape(-1, 2)

# Extract latitude and longitude values separately for easier use in plotting
pixel_lats = coordinates[:, 0]  # Array of latitudes for each pixel
pixel_lons = coordinates[:, 1]  # Array of longitudes for each pixel

# Extract latitude and longitude values from the GRD dataset (coarser resolution grid)
lat_GRD = data_GRD['latitude']
lon_GRD = data_GRD['longitude']

# Stack latitude and longitude values from the GRD dataset
lat_lon_GRD = np.dstack((lat_GRD, lon_GRD))

# Reshape the stacked array into a 2D format where each row contains a (lat, lon) pair
coordinates2 = lat_lon_GRD.reshape(-1, 2)

# Extract latitude and longitude values separately for plotting or further analysis
pixel_lats_GRD = coordinates2[:, 0]  # Latitude values for GRD pixels
pixel_lons_GRD = coordinates2[:, 1]  # Longitude values for GRD pixels

# %% [markdown]
# ### Tb Threshold Mapping & Visualization
#
# This code generates a regional map of new optimized Tb thresholds estimated in previous blocks. It visualizes site-specific thresholds, overlays shapefile boundaries (based on your need, for exmaple here we have the shapefile of Alaska ecoregions) or validation sites (based on your need, for exmaple here we have the SNOTEL sites that we used for algorithm calibartion and validations), and plots the results on a Basemap.

# %%
# Read the CSV files and drop columns with all NaN values
df = pd.read_csv('/home/mabb21/Research/AKEcoregions/Filtered_Sites_with_SnowClasses.csv').dropna(axis=1, how='all') ## SNOTEL sites

# Threshold file created in previous blocks
Thresholds = pd.read_csv(os.path.join(ThresholdDir, "thresholds2003_02.csv")).dropna(axis=1, how='all')  # Tb thresholds


# Assign unique IDs to each site
df['SiteID'] = df.index.astype(str)

# Read the shapefile of interest
shp_file = '/home/mabb21/Research/Sites/Ecoregion/AKEcoregions105106.shp'  ## Alaska Ecoregions
gdf = gpd.read_file(shp_file)


# Choose the year for plot
year = 2003
array = Thresholds['Tb Threshold']
title = f"{sensor_SIR} - {SiteLabel} - Optimized Tb Thresholds - ({year})"

# Calculate average of Tb Thresholds
avg_value = array.mean()


# Create figure and basemap instance
fig = plt.figure(figsize=(8, 8))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
m = Basemap(projection='stere',
            lon_0=(lon_start + lon_end) / 2,
            lat_0=(lat_start + lat_end) / 2,
            lat_ts=90.,
            llcrnrlat=lat_start - 2.0,
            urcrnrlat=lat_end + 3.0,
            llcrnrlon=lon_start - 5.0,
            urcrnrlon=lon_end + 3.0,
            rsphere=6371200.,
            resolution='l',
            area_thresh=10000,
            epsg=3857)
m.drawcoastlines()
m.drawcountries()
m.drawstates()

parallels = np.arange(0., 90, 0.5)
m.drawparallels(parallels, labels=[1, 0, 0, 0], fontsize=10, labelstyle="+/-")

meridians = np.arange(0, 360., 1)
m.drawmeridians(meridians, labels=[0, 0, 0, 1], fontsize=10, labelstyle="+/-", rotation=45)

m.arcgisimage(service='World_Physical_Map', xpixels=1500, verbose=True)

# Plot pixel data
x, y = m(pixel_lons, pixel_lats)
im = m.scatter(x, y, c=array, s=30, marker='s', lw=0, cmap='BuPu_r', alpha=.6)

# Plot shapefile
for geom in gdf.geometry:
    if geom.geom_type == 'Polygon':
        xs, ys = m(*np.array(geom.exterior.xy))
        m.plot(xs, ys, 'k-', lw=1)
    elif geom.geom_type == 'Point':
        x, y = m(geom.x, geom.y)
        m.plot(x, y, 'ro', markersize=5)


# Plotting the sites and preparing legend
handles = []  # Store handles for the legend
legend_entries = []  # Store labels for the legend
for index, row in df.iterrows():
    x, y = m(row['lon_start'], row['lat_start'])
    handle, = m.plot(x, y, 'ro', markersize=5)  # Plot each site as a red dot
    handles.append(handle)
    legend_entries.append(f"{row['SiteID']}: {row['Site']}")  # Add site labels

    # Annotate each site with its name or ID
    plt.text(x, y, f"{row['SiteID']}", fontsize=15, ha='left', va='bottom')

# Create handles for colorbar lines
colorbar_handles = [
    plt.Line2D([0], [0], color='green', linestyle='-', label=f'Avg: {avg_value:.1f}')
]

# Add colorbar labels to the legend entries
colorbar_labels = [f"Avg Threshold: {avg_value:.1f}"]

# Combine site and colorbar handles/labels
combined_handles = handles + colorbar_handles
combined_labels = legend_entries + colorbar_labels

# Add unified legend
ax.legend(combined_handles, combined_labels, loc='upper left', title="Legend", fontsize=10)


plt.title(title)
#plt.clim(30, 145)

# Configure colorbar
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax, label='Tb Threshold (K)')

# Add horizontal lines for min, max, and average values on the colorbar
cax.axhline(avg_value, color='green', linestyle='-', label=f'Avg: {avg_value:.1f}')


# Save the figure
output_file_path = os.path.join(ThresholdDir, "TbThresholdMap.png")
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Show the plot
plt.show()
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/export?bbox=-16475284.637404488,8625823.200203594,-15473409.220265027,10446997.314774934&bboxSR=3857&imageSR=3857&size=1500,2726&dpi=96&format=png32&transparent=true&f=image

# %% [markdown]
# # Running the DAV Algorithm for Region-Based Optimization:
# The rules and methodology remain the same as those used for single-site analysis. The only difference is that this version uses a loop to process all pixels within the bounding box extracted previously. Then, it saves the optimized thresholds as a CSV file in the ThresholdDir (saving directory), which includes these columns >> Site, Latitude, Longitude, x, y, DAV_Threshold_90_Percentile, DAV_Threshold_95_Percentile, DAV Threshold (Average)
#
# ### Important not about the next block of code for DAV:
#
# It's important to have at least two years in 'subYears' to avoid certain errors, including the year of interest and the year after, for example, for 2003, you should also include 2004 in subYears.
#
# ## Avoiding Redundant Processing of rSIR Pixels in Each GRD Pixel
# In this implementation, as we did for the region-based Tb algorithm, we use the DAV data for all 64 pixels in order to have maximum data for  DAV time series analysis, which means it will repeat the same process with the same data for each rSIR pixel or site. To avoid this, we ensure that the DAV threshold computation is performed only once for each GRD pixel, even though multiple rSIR pixels exist within it. Instead of repeating the threshold calculation for every individual rSIR pixel, we implement an efficient caching mechanism using the dictionary `processed_GRD_pixels`. Please note that we can also run the process using DAV data relevant to the single rSIR pixel, but we may have data gaps or not a very continuous time series. By using this method, we increase efficiency, reduce processing time, and ensure consistency in assigning DAV thresholds across all rSIR pixels within the same GRD pixel.
#
#
# ### How We Avoid Redundant Computation:
# 1. Identify Unique GRD Pixels
# 2. Check if the GRD Pixel is Already Processed
# 3. Compute DAV Threshold Only Once per GRD Pixel
#    - If a new GRD pixel is encountered, the script processes only one rSIR pixel within it.
# 4. Assign the Same Threshold to All rSIR Pixels in That GRD Pixel
#    - Once a threshold is computed for a GRD pixel, it is directly assigned to all its corresponding rSIR pixels without reprocessing.
#
# ### Why This Approach is Efficient?
# - Minimizes redundant computation → Each GRD pixel is processed only once, significantly reducing computational cost.
# - Faster execution → Instead of processing all rSIR pixels individually, the loop efficiently assigns precomputed values.
# - Memory optimization → Storing previously computed values in a dictionary prevents unnecessary function calls and data storage.
#
# ---

# %%
### This block is the optimized DAV algorithm for the region and year of interest!

# Subset of years
# It's important to have at least two years in 'subYears' to avoid certain errors, including the year of interest and the year after, Cont'd...
# for example, for 2003, you should also include 2004. 
subYears = Years[8:11]

# Set the year of interest
year = 2003

# Dictionary to store calculated DAV thresholds for each GRD pixel
processed_GRD_pixels = {}

# Function to extract and plot Tb and DAV for the specified year
def TbYear(CETB_data, DAV, cal_date, cal_ysear, year):
    """
    Extracts the time-series of Tb and DAV for the given year.

    Parameters:
        CETB_data: The CETB data array (brightness temperature data).
        DAV: The DAV data array (Diurnal Amplitude Variations Melt Algorithm).
        cal_date: Array of datetime objects corresponding to the CETB data.
        cal_year: Array of years corresponding to the CETB data.
        year: The year of interest to filter data.

    Returns:
        DataFrame containing the DAV data for the specified year and site.
    """
    # Create a list of pixel indices for the y and x dimensions
    y_dims_list = list(range(len(CETB_data[0, :, 0])))  # y-dimension pixel indices
    x_dims_list = list(range(len(CETB_data[0, 0, :])))  # x-dimension pixel indices

    # Boolean mask to filter data for the year of interest
    thisYr = cal_year == year

    # Iterate over all y and x pixel indices to plot the time series (if needed)
    for i in y_dims_list:
        for j in x_dims_list:
            # Create DataFrames for DAV time series for the selected year
            DAV_df = pd.DataFrame(DAV[thisYr, i, j], index=cal_date[thisYr])

    # Return the final DataFrame containing DAV for the specified year
    return DAV_df

# Initialize list to store DAV thresholds for each site
DAV_Threshold_Percentile = []

# Loop through all sites
for index, row in Sites_df.iterrows():
    # Extract site and coordinates
    Site = row['Site']
    lat_start = row['lat_start']
    lon_start = row['lon_start']
    x = row['x']
    y = row['y']

    # Compute the corresponding GRD pixel coordinates
    rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_start, lon_start, lon_start)
    grd_pixel_key = tuple(rows_cols_GRD)  # Unique identifier for each GRD pixel

    # If this GRD pixel has already been processed, assign the stored DAV threshold
    if grd_pixel_key in processed_GRD_pixels:
        DAV_threshold_Percentile90, DAV_threshold_Percentile95, DAV_Average = processed_GRD_pixels[grd_pixel_key]
        print(f"Assigning existing DAV thresholds for Site {Site} in GRD {grd_pixel_key}: "
              f"90%: {DAV_threshold_Percentile90:.2f} K, 95%: {DAV_threshold_Percentile95:.2f} K")
    else:
        print(f"Processing site: {Site} for GRD {grd_pixel_key}")

        # Calculate the envelope of coordinates for 64 SIR pixels
        rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)

        # Read brightness temperature dataset
        data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, subYears, 
                                 rows_cols_env[0], rows_cols_env[1], 
                                 rows_cols_env[2], rows_cols_env[3])

        # Step 1: Calculate DAV using an existing function
        DAV_SIR = calc_DAV(data_SIR['TB'])

        # Step 2: Extract the Tb and DAV data for the specified year
        DAV_df = TbYear(data_SIR['TB'], DAV_SIR, data_SIR['cal_date'], data_SIR['cal_year'], year)

        # Step 3: Rename the DataFrame column to 'DAV' for clarity
        DAV_df.columns = ['DAV']

        # Step 4: Calculate the 90th and 95th percentiles of DAV values, as well as their average
        DAV_threshold_Percentile90 = DAV_df['DAV'].quantile(0.90)  # 90% threshold
        DAV_threshold_Percentile95 = DAV_df['DAV'].quantile(0.95)  # 95% threshold
        DAV_Average = np.mean([DAV_threshold_Percentile90, DAV_threshold_Percentile95])

        print(f"DAV Threshold (90% Percentile) at {Site}, Year {year}: {DAV_threshold_Percentile90:.2f} K")
        print(f"DAV Threshold (95% Percentile) at {Site}, Year {year}: {DAV_threshold_Percentile95:.2f} K")
        print(f"DAV Threshold (Average) at {Site}, Year {year}: {DAV_Average:.2f} K")

        # Store computed DAV thresholds in the dictionary
        processed_GRD_pixels[grd_pixel_key] = (DAV_threshold_Percentile90, DAV_threshold_Percentile95, DAV_Average)

    # Append the site and threshold to DAV_threshold list
    DAV_Threshold_Percentile.append((Site, lat_start, lon_start, x, y, DAV_threshold_Percentile90, DAV_threshold_Percentile95, DAV_Average))

# After processing all sites, save thresholds to a single CSV file
csv_path = os.path.join(ThresholdDir, f"DAVthresholds_AllSites_{year}.csv")
with open(csv_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Site', 'Latitude', 'Longitude', 'x', 'y', 'DAV_Threshold_90_Percentile', 'DAV_Threshold_95_Percentile', 'DAV Threshold (Average)'])
    writer.writerows(DAV_Threshold_Percentile)

print(f"CSV file saved with DAV threshold values for all sites: {csv_path}")

# %% [markdown]
# ### DAV Threshold Mapping & Visualization
#
# This code generates a regional map of new optimized DAV thresholds estimated in previous blocks. It visualizes site-specific thresholds, overlays shapefile boundaries (based on your need, for exmaple here we have the shapefile of Alaska ecoregions) or validation sites (based on your need, for exmaple here we have the SNOTEL sites that we used for algorithm calibartion and validations), and plots the results on a Basemap.

# %%
# Read the CSV file containing filtered site data with snow classifications 
# and drop columns that contain only NaN values to clean up the dataset.
df = pd.read_csv('/home/mabb21/Research/AKEcoregions/Filtered_Sites_with_SnowClasses.csv').dropna(axis=1, how='all')

# Read the DAV threshold data for all sites for the specified year (2003),
# and drop columns with all NaN values.
DAV_Thresholds = pd.read_csv(os.path.join(ThresholdDir, "DAVthresholds_AllSites_2003.csv")).dropna(axis=1, how='all')

# Assign unique Site IDs to each row by converting the index to a string
df['SiteID'] = df.index.astype(str)

# Read the shapefile that contains ecoregion boundaries
shp_file = '/home/mabb21/Research/Sites/Ecoregion/AKEcoregions105106.shp'
gdf = gpd.read_file(shp_file)

# Define the year of interest
year = 2003

# Extract the DAV threshold values (90th percentile) for visualization
array = DAV_Thresholds['DAV_Threshold_90_Percentile']

# Define the title for the plot
title = f"{sensor_SIR} - {SiteLabel} - Optimized DAV Thresholds - ({year})"

# Calculate the average of the DAV thresholds for all sites
avg_value = array.mean()

# Create a figure and a Basemap instance for spatial visualization
fig = plt.figure(figsize=(8, 8))
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# Initialize the map using a stereographic projection centered on the region of interest
m = Basemap(projection='stere',
            lon_0=(lon_start + lon_end) / 2,  # Central longitude
            lat_0=(lat_start + lat_end) / 2,  # Central latitude
            lat_ts=90.,
            llcrnrlat=lat_start - 2.0,  # Lower left latitude
            urcrnrlat=lat_end + 3.0,    # Upper right latitude
            llcrnrlon=lon_start - 5.0,  # Lower left longitude
            urcrnrlon=lon_end + 3.0,    # Upper right longitude
            rsphere=6371200.,  # Earth's radius in meters
            resolution='l',  # Low-resolution map
            area_thresh=10000,
            epsg=3857)  # EPSG code for the projection

# Draw coastlines, country borders, and state boundaries
m.drawcoastlines()
m.drawcountries()
m.drawstates()

# Draw latitude and longitude grid lines
parallels = np.arange(0., 90, 0.5)
m.drawparallels(parallels, labels=[1, 0, 0, 0], fontsize=10, labelstyle="+/-")

meridians = np.arange(0, 360., 1)
m.drawmeridians(meridians, labels=[0, 0, 0, 1], fontsize=10, labelstyle="+/-", rotation=45)

# Add a basemap background image
m.arcgisimage(service='World_Physical_Map', xpixels=1500, verbose=True)

# Convert site coordinates to the map projection and plot them as squares
x, y = m(pixel_lons, pixel_lats)
im = m.scatter(x, y, c=array, s=30, marker='s', lw=0, cmap='BuPu_r', alpha=.6)

# Plot shapefile geometries on the map
for geom in gdf.geometry:
    if geom.geom_type == 'Polygon':  # If it's a polygon, plot its boundary
        xs, ys = m(*np.array(geom.exterior.xy))
        m.plot(xs, ys, 'k-', lw=1)
    elif geom.geom_type == 'Point':  # If it's a point, mark it in red
        x, y = m(geom.x, geom.y)
        m.plot(x, y, 'ro', markersize=5)

# Plot site locations and prepare the legend
handles = []  # List to store handles for the legend
legend_entries = []  # List to store legend labels

for index, row in df.iterrows():
    x, y = m(row['lon_start'], row['lat_start'])  # Convert site coordinates to map projection
    handle, = m.plot(x, y, 'ro', markersize=5)  # Plot each site as a red dot
    handles.append(handle)
    legend_entries.append(f"{row['SiteID']}: {row['Site']}")  # Add site labels

    # Annotate each site with its ID
    plt.text(x, y, f"{row['SiteID']}", fontsize=15, ha='left', va='bottom')

# Create handles for the colorbar and add an average value marker
colorbar_handles = [
    plt.Line2D([0], [0], color='green', linestyle='-', label=f'Avg: {avg_value:.1f}')
]

# Add colorbar labels to the legend
colorbar_labels = [f"Avg Threshold: {avg_value:.1f}"]

# Combine site and colorbar handles/labels
combined_handles = handles + colorbar_handles
combined_labels = legend_entries + colorbar_labels

# Add a unified legend
ax.legend(combined_handles, combined_labels, loc='upper left', title="Legend", fontsize=10)

# Set the plot title
plt.title(title)

# Configure and add a colorbar for the DAV threshold values
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
plt.colorbar(im, cax=cax, label='DAV Threshold (K)')

# Add a horizontal line for the average threshold value on the colorbar
cax.axhline(avg_value, color='green', linestyle='-', label=f'Avg: {avg_value:.1f}')

# Save the figure to the output directory
output_file_path = os.path.join(ThresholdDir, "DAVThresholdMap.png")
plt.savefig(output_file_path, bbox_inches='tight', dpi=300)

# Display the plot
plt.show()
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/export?bbox=-16475284.637404488,8625823.200203594,-15473409.220265027,10446997.314774934&bboxSR=3857&imageSR=3857&size=1500,2726&dpi=96&format=png32&transparent=true&f=image

# %% [markdown]
# # Analysis of SSD for melt detection

# %% [markdown]
# ## Extracting DAV for a Specific Site (e.g., `SNOTEL1`) and Year
#
# This section is pasted from previous blocks to allow selecting a single site using `SiteLabel` and extracting DAV data for SSD melt detection.

# %%
SiteLabel='SNOTEL1'
lat_start, lat_end, lon_start, lon_end, Site=get_site_boundaries(SiteLabel)
lat_start, lat_end, lon_start, lon_end, Site

# for 2003, you should also include 2004. 
subYears = Years[8:11]

# Set the year of interest
year = 2003

# Function to extract and plot Tb and DAV for the specified year
def TbYear(CETB_data, DAV, cal_date, cal_year, year):
    """
    Extracts the time-series of Tb and DAV for the given year.
    
    Parameters:
        CETB_data: The CETB data array (brightness temperature data).
        DAV: The DAV data array (Diurnal Amplitude Variations Melt Algorithm).
        cal_date: Array of datetime objects corresponding to the CETB data.
        cal_year: Array of years corresponding to the CETB data.
        year: The year of interest to filter data.

    Returns:
        DataFrame containing the DAV data for the specified year and site.
    """
    # Create a list of pixel indices for the y and x dimensions
    y_dims_list = list(range(len(CETB_data[0, :, 0])))  # y-dimension pixel indices
    x_dims_list = list(range(len(CETB_data[0, 0, :])))  # x-dimension pixel indices

    # Boolean mask to filter data for the year of interest
    thisYr = cal_year == year

    # Iterate over all y and x pixel indices to plot the time series (if needed)
    for i in y_dims_list:
        for j in x_dims_list:
            # Create DataFrames for DAV time series for the selected year
            DAV_df = pd.DataFrame(DAV[thisYr, i, j], index=cal_date[thisYr])

    # Return the final DataFrame containing DAV for the specified year
    return DAV_df

# Print a message indicating which site is being processed
print(f"Processing site: {Site}")

# Calculate the row and column coordinates of the GRD pixels corresponding to the site's lat and lon
rows_cols_GRD = coords(datadir_GRD, prefix_GRD, lat_start, lat_start, lon_start, lon_start)
        
# Calculate the envelope of coordinates for 64 SIR pixels
rows_cols_env = tuple(np.array(rows_cols_GRD) * sir_2_grd_factor)
        
# Read brightness temperature data for the calculated coordinates from the SIR dataset
data_SIR = read_Tb_whole(datadir_SIR, prefix_SIR, subYears, rows_cols_env[0], rows_cols_env[1], rows_cols_env[2], rows_cols_env[3])

# Step 1: Calculate DAV using an existing function (assumed to be implemented elsewhere)
DAV_SIR = calc_DAV(data_SIR['TB'])  # DAV is calculated based on TB (brightness temperature) data


# Step 2: Extract the Tb and DAV data for the specified year
DAV_df = TbYear(data_SIR['TB'], DAV_SIR, data_SIR['cal_date'], data_SIR['cal_year'], year)

# Step 3: Rename the DataFrame column to 'DAV' for clarity
DAV_df.columns = ['DAV']
# Out:
# Processing site: Monument Creek, AK
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2003.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2004.TB.nc...
# Next filename=/home/mabb21/ceph/jmr204group/CETB_cubes/F13_SSMI/N/nc_cubes/cubes_AKYukon/CETB.cubefile.AKYukon.F13_SSMI-37V-SIR-CSU-v1.3.2005.TB.nc...

# %% [markdown]
# ## Extracting and Plotting SWE and Temperature Time Series
#
# This section retrieves Snow Water Equivalent (SWE) and Temperature (Temp) time series data from SNOTEL for a selected site and year.
# It applies unit conversions, outlier filtering, and determines the maximum SWE date when temperatures exceed 268.15 K (actual melting threshold).
# The results are visualized using **dual-axis time series plots**, highlighting **max SWE, temperature variations, and critical thresholds**.

# %%
#SWE and Temp Time series and Max SWE plots and difference, actual
from datetime import datetime
import ulmo
import pytz
import matplotlib.dates as mdates

year = 2003


# Conversion functions
def fahrenheit_to_kelvin(f):
    return (f - 32) * 5/9 + 273.15
def inches_to_mm(inches):
    return inches * 25.4
    
# Modify the fetch function to handle multiple variables
def snotel_fetch(sitecode, variable_codes, start_date='2001-01-01', end_date='today'):
    data = {}
    for variablecode in variable_codes:
        try:
            site_values = ulmo.cuahsi.wof.get_values(wsdlurl, sitecode, variablecode, start=start_date, end=end_date)  
            values_df = pd.DataFrame.from_dict(site_values['values'])
            values_df['datetime'] = pd.to_datetime(values_df['datetime'], utc=True)
            values_df = values_df.set_index('datetime')
            values_df['value'] = pd.to_numeric(values_df['value']).replace(-9999, np.nan)
            values_df = values_df[values_df['quality_control_level_code'] == '1']
            data[variablecode] = values_df
        except:
            print(f"Unable to fetch data for {sitecode} with variable {variablecode}")
    return data


wsdlurl = 'https://hydroportal.cuahsi.org/Snotel/cuahsi_1_1.asmx?WSDL'


# Define the site of interest
SiteLabel = 'SNOTEL1'
lat_start, lat_end, lon_start, lon_end, Site=get_site_boundaries(SiteLabel)

# Read the dataset
sites_df_custom = pd.read_csv('/home/mabb21/Research/Sites/Ecoregion/Filtered_Sites_Ecoregions.csv')

# Drop rows where 'SNOTEL' column is NaN
sites_df_custom = sites_df_custom.dropna(subset=['SNOTEL'])

# Filter for the site of interest
site_of_interest = sites_df_custom[sites_df_custom['Site'] == Site]

# If the site exists, extract its boundaries
if not site_of_interest.empty:
    lat_start, lat_end, lon_start, lon_end, Site = get_site_boundaries(SiteLabel)
    print(f"Processing site: {Site} with boundaries lat({lat_start}, {lat_end}) lon({lon_start}, {lon_end})")
else:
    print(f"Site '{SiteLabel}' not found in the dataset.")



variable_codes = ['SNOTEL:WTEQ_D', 'SNOTEL:TAVG_D']
snotel_ids = site_of_interest['SNOTEL'].unique()
start_date = datetime(year, 1, 1, tzinfo=pytz.UTC)
end_date = datetime(year, 12, 31, tzinfo=pytz.UTC)

# Loop through each site
for index, row in site_of_interest.iterrows():
    sitecode = row['SNOTEL']
    if not isinstance(sitecode, str):
        continue

    print(f"Processing site: {sitecode}")
    snotel_data = snotel_fetch(sitecode, variable_codes, start_date, end_date)
    Site = row['Site']
    print(f"Processing site: {Site}")

    if 'SNOTEL:TAVG_D' in snotel_data and 'SNOTEL:WTEQ_D' in snotel_data:
        temp_df = snotel_data['SNOTEL:TAVG_D']
        swe_df = snotel_data['SNOTEL:WTEQ_D']
        
        if temp_df is not None and not temp_df.empty and swe_df is not None and not swe_df.empty:
            temp_df['value'] = temp_df['value'].apply(fahrenheit_to_kelvin)
            Q1 = temp_df['value'].quantile(0.25)
            Q3 = temp_df['value'].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            filtered_temp_df = temp_df[(temp_df['value'] >= lower_bound) & (temp_df['value'] <= upper_bound)]
                         
            swe_df['value'] = swe_df['value'].apply(inches_to_mm)

            if not isinstance(swe_df.index, pd.DatetimeIndex):
                swe_df.index = pd.to_datetime(swe_df.index)

            combined_df = pd.merge(swe_df, filtered_temp_df, left_index=True, right_index=True, suffixes=('_swe', '_temp'))

            # Adding conditions for the next three days
            for i in range(1, 1):
                combined_df[f'next_day_temp_{i}'] = combined_df['value_temp'].shift(-i)

            valid_swe_days = combined_df[
                (combined_df['value_temp'] > 268.15) 
                #(combined_df['next_day_temp_1'] > 268.15) &
                #(combined_df['next_day_temp_2'] > 268.15) &
                #(combined_df['next_day_temp_3'] > 268.15) &
                #(combined_df['next_day_temp_4'] > 268.15) &
                #(combined_df['next_day_temp_5'] > 268.15) &
                #(combined_df['next_day_temp_6'] > 268.15) &
                #(combined_df['next_day_temp_7'] > 268.15)
            ]

            valid_swe_days = valid_swe_days[(valid_swe_days.index >= start_date) & (valid_swe_days.index <= end_date)]
            valid_swe_days = valid_swe_days[valid_swe_days.index.month <= 7]

            while not valid_swe_days.empty:
                max_swe_date = valid_swe_days['value_swe'].idxmax()
                max_swe_day_of_year = max_swe_date.timetuple().tm_yday
                if valid_swe_days.loc[max_swe_date, ['value_temp']].min() > 268.15:
                    #, 'next_day_temp_1', 'next_day_temp_2', 'next_day_temp_3'
                    break
                valid_swe_days = valid_swe_days.drop(max_swe_date)

            if not valid_swe_days.empty:
                fig, ax1 = plt.subplots(figsize=(10, 5))
                ax2 = ax1.twinx()
                ax1.plot(swe_df.index, swe_df['value'], label='SWE (mm)', color='tab:blue', zorder=1)
                ax1.axvline(x=max_swe_date, color='black', linestyle='--', label=f'Max SWE on day {max_swe_day_of_year}')
                ax1.set_ylabel('Snow Water Equivalent (mm)', color='tab:blue')
                ax2.plot(filtered_temp_df.index, filtered_temp_df['value'], label='Temp (K)', color='tab:red', zorder=2)
                ax2.axhline(y=268.15, color='gray', linestyle='--', linewidth=2, label='Air Temperature Threshold (268.15 K)')
                ax2.set_ylabel('Air Temperature (K)', color='tab:red')
                ax1.legend(loc='upper left')
                ax2.legend(loc='upper right')
                plt.title(f"{Site} ({row['lat_start']}, {row['lon_start']})")
                plt.grid(True)
                ax1.xaxis.set_major_locator(mdates.MonthLocator())
                ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
                plt.xticks(rotation=45)
                plt.tight_layout()
            else:
                print(f"No valid maximum SWE found for site {sitecode}")
        else:
            print(f"No data to plot for site {sitecode}")
# Out:
# Processing site: Monument Creek, AK with boundaries lat(65.07833, 65.07833) lon(-145.87067, -145.87067)
# Processing site: SNOTEL:949_AK_SNTL
# Processing site: Monument Creek, AK

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import scipy.io as sio


# build the string that is the index to the SIR cell closest to our site
# note that this is likely inside the SIR cell envelope
rows_cols = coords(datadir_SIR, prefix_SIR, lat_start, lat_start, lon_start, lon_start)
Site_nearest_row_col = "%s,%s" % (str(rows_cols[0]),str(rows_cols[2])) 

#Define the path to save the plot
save_path = os.path.join(ThresholdDir, f"{Site}_{year}_{sensor_SIR}TimeSeries_StdPlot.png")

year = 2003

# Ensure the index is in datetime format
DAV_df.index = pd.to_datetime(DAV_df.index)

# reate a date range starting from October of the previous year to the end of the year of interest
start_date = f"{year}-01-01"
end_date = f"{year}-12-31"

# Filter the DataFrame for the specified date range
DAV_df = DAV_df[start_date:end_date]


# load dataframe of Tb GRD for plotting Tb on specified day and observation
#Tb_std_dev_GRD = read_Tb_std_dev(datadir_GRD, prefix_GRD, subYears,
                                 #rows_cols_GRD[0],rows_cols_GRD[1],rows_cols_GRD[2],rows_cols_GRD[3])
# slice of dataframe described above
#Tb_sd_frame_GRD=pd.DataFrame(Tb_std_dev_GRD[:,0,0], index=data_GRD['cal_date'])
#Tb_sd_frame_GRD.columns = ['GRD SSD']

# Ensure the index is in datetime format
#Tb_sd_frame_GRD.index = pd.to_datetime(Tb_sd_frame_GRD.index)

# Filter the DataFrame for the specified date range
#Tb_sd_frame_GRD = Tb_sd_frame_GRD[start_date:end_date]


#need to run this cell for the max DAV to work
y_dims_list=list(range(len(data_SIR['TB'][0,:,0])))  # creates a list of the y-dimension pixel indices, used for plotting
x_dims_list=list(range(len(data_SIR['TB'][0,0,:])))	# creates a list of the x-dimension pixel indices, for plotting
y_s=list(range(rows_cols_env[0],rows_cols_env[1]))  # makes a list of the y(row) numbers so the dataframe of early melt events can be indexed
x_s=list(range(rows_cols_env[2],rows_cols_env[3]))  # makes a list of the x(col) numbers so the dataframe of early melt events can be indexed

# load dataframe of Tb SIR for plotting Tb on specified day and observation
Tb_frame=pd.DataFrame()
for i in y_dims_list:
    for j in x_dims_list:
        column=pd.DataFrame(data=data_SIR['TB'][:,i,j], columns=[str(y_s[i])+','+str(x_s[j])])
        Tb_frame=pd.concat([Tb_frame,column],axis=1)
Tb_frame.index=data_SIR['cal_date']
# compute std dev of the 64 SIR pixels
Tb_std_64=Tb_frame.std(axis=1)
Tb_std=pd.DataFrame(Tb_std_64)
Tb_std.columns = ['SSD']

# Ensure the index is in datetime format
Tb_std.index = pd.to_datetime(Tb_std.index)


# Filter the DataFrame for the specified date range
Tb_std = Tb_std[start_date:end_date]
# Ensure the index is in datetime format
Tb_std.index = pd.to_datetime(Tb_std.index)

# Fill or interpolate missing values
Tb_std['SSD'] = Tb_std['SSD'].interpolate(method='linear')

Tb_nearest=Tb_frame[Site_nearest_row_col]
Tb_nearest=Tb_nearest.to_frame()
Tb_nearest.columns=['TB']
Tb_nearest.index = pd.to_datetime(Tb_nearest.index)
Tb_nearest = Tb_nearest[start_date:end_date]


MeltDate = pd.to_datetime('2003-04-13')


######### 
# Calculate the 15th percentile of the SSD data
percentile_60 = Tb_std['SSD'].quantile(0.6)
percentile_99 = Tb_std['SSD'].quantile(0.993)

# Decompose the time series to extract the trend
Tb_std_Clean = Tb_std['SSD'].dropna()
Tb_std_Clean = pd.DataFrame(Tb_std_Clean, columns=['SSD'])
decomposition = seasonal_decompose(Tb_std_Clean['SSD'], model='additive', period=30)  # Assuming daily data and monthly seasonality
trend = decomposition.trend

# Compute the gradient of the SSD time series
gradient = np.gradient(Tb_std['SSD'].values)

# Clean the gradient by removing NaN and infinite values
gradient_clean = gradient[~np.isnan(gradient) & ~np.isinf(gradient)]

# Check for empty or zero-variance gradient
if gradient_clean.size == 0:
    print("Error: Gradient array is empty!")
elif np.std(gradient_clean) == 0:
    print("Warning: No variance in the gradient. Thresholds may not be meaningful.")
else:
    # Compute the positive and negative thresholds
    pos_threshold = np.mean(gradient_clean) + 3 * np.std(gradient_clean)
    neg_threshold = np.mean(gradient_clean) - 3 * np.std(gradient_clean)

    print(f"Positive Threshold: {pos_threshold}")
    print(f"Negative Threshold: {neg_threshold}")

    # Find indices of values above the positive threshold
    pos_indices = np.where(gradient > pos_threshold)[0]

    # List to store the dates where positive is followed by negative threshold
    valid_anomaly_dates = []

    # Loop through positive anomalies and search for a negative value in the next 3 points
    #for pos_idx in pos_indices:
        #for offset in range(1, 7):  # Checking the next 3 points
            #next_idx = pos_idx + offset
            #if next_idx < len(gradient) and gradient[next_idx] < neg_threshold:
                #valid_anomaly_dates.append(Tb_std.index[pos_idx])
                #break  # Stop searching after finding the first valid negative gradient


    
    valid_anomaly_dates = Tb_std.index[pos_indices]
    # Remove duplicate dates
    valid_anomaly_dates = pd.to_datetime(valid_anomaly_dates).unique()
    anomaly_after_march = valid_anomaly_dates[valid_anomaly_dates > f"{year}-03-31"]

    # Print the detected valid anomaly dates
    print("Detected valid positive-to-negative threshold dates:")
    print(anomaly_after_march)

    # --- Plot Results ---
    fig, axes = plt.subplots(2, 1, figsize=(14, 10), sharex=True)

    # Find the date and value of the maximum trend
    trend_after_march = trend[trend.index > f"{year}-03-31"]  # Adjust the year as needed or make it dynamic
    max_trend_value = trend_after_march.max()
    max_trend_date = trend_after_march.idxmax()

    # Calculate where the trend crosses the 60th percentile
    sign_change = (trend - percentile_60) * (trend.shift(-1) - percentile_60) < 0  # Strict sign change condition
    intersection_points = trend[sign_change]

    # --- Plot SSD on Primary Axis (Top Subplot) ---
    axes[0].plot(Tb_std.index, Tb_std['SSD'], color='#1b9e77', label='SSD Time Series', linewidth=2)
    axes[0].plot(Tb_std_Clean.index, trend, color='blue', label='SSD Trend Component', linewidth=2, linestyle='--')
    axes[0].axvline(x=max_trend_date, color='purple', linestyle='--', linewidth=3, 
                label=f'Max Trend on {max_trend_date.strftime("%Y-%m-%d")}', zorder=4)
    axes[0].axhline(y=percentile_60, color='navy', linestyle='--', 
                    label=f'CETB SSD 60th Percentile: {percentile_60:.2f} K', linewidth=2)
    axes[0].axhline(y=percentile_99, color='tab:pink', linestyle='--', 
                    label=f'CETB SSD 99.3th Percentile: {percentile_99:.2f} K', linewidth=2)
    # Highlight intersection points with circles
    filtered_intersection = intersection_points[(intersection_points.index > f"{year}-03-31") & (intersection_points.index < f"{year}-09-01")]
    axes[0].scatter(filtered_intersection.index, filtered_intersection.values, color='red', s=120, 
                    label='Trend & 60th Percentile Intersections', edgecolor='black', zorder=5)

    axes[0].axvline(x=MeltDate, color='red', linestyle='--', label='2003-04-13')
    axes[0].set_ylabel('SSD (K)', fontsize=14, color='#1b9e77')
    axes[0].grid(True)

    # Highlight valid anomaly points on the SSD time series plot
    intersection_date = filtered_intersection.index[0]  # Assuming we want the first intersection date

    # Find the maximum trend after March of the given year
    trend_after_march = trend[trend.index > f"{year}-03-31"]
    if trend_after_march.empty:
        print("No trend data available after March.")
    else:
        max_trend_value = trend_after_march.max()
        max_trend_date = trend_after_march.idxmax()

        # Convert the max trend date to its index in the gradient array
        if max_trend_date in Tb_std.index:
            max_trend_idx = Tb_std.index.get_loc(max_trend_date)

            # Get the SSD value on the day of the max trend
            max_trend_ssd = Tb_std.loc[max_trend_date, 'SSD']

            # Check if the gradient at or near this date is above the positive threshold
            window = 14  # Check up to the next 14 points/7 days for a sudden increase
            sudden_increase_found = False
#### Add codes below because it should be after the max trend location
            for offset in range(0, window + 1):
                check_idx = max_trend_idx + offset
                if check_idx < len(gradient) and gradient[check_idx] > pos_threshold:
                    increase_date = Tb_std.index[check_idx]
                    increase_ssd = Tb_std.loc[increase_date, 'SSD']

                    # Search the SSD values on the sudden gradient increase date, the day before, and the day after
                    max_ssd_date = increase_date
                    max_ssd_value = increase_ssd

                    # Check the day before the gradient spike (-1 day), if needed
                    prev_day_idx = check_idx - 1
                    if prev_day_idx >= 0:
                        prev_increase_date = Tb_std.index[prev_day_idx]
                        prev_increase_ssd = Tb_std.loc[prev_increase_date, 'SSD']
                        if prev_increase_ssd > max_ssd_value:
                            max_ssd_value = prev_increase_ssd
                            max_ssd_date = prev_increase_date

                    # Check the day after the gradient spike (+1 day)
                    next_day_idx = check_idx + 1
                    if next_day_idx < len(Tb_std):
                        next_increase_date = Tb_std.index[next_day_idx]
                        next_increase_ssd = Tb_std.loc[next_increase_date, 'SSD']
                        if next_increase_ssd > max_ssd_value:
                            max_ssd_value = next_increase_ssd
                            max_ssd_date = next_increase_date

                        # Print the results for max SSD within the 3-day window
                    print(f"Max trend after March occurs on {max_trend_date.strftime('%Y-%m-%d %H:%M:%S')} "
                          f"(Trend Value: {max_trend_value:.2f}, SSD: {max_trend_ssd:.2f}).")
                    print(f"Sudden gradient increase detected on {increase_date.strftime('%Y-%m-%d %H:%M:%S')} (SSD: {increase_ssd:.2f}).")
                    print(f"Actual SSD increase occurs on {max_ssd_date.strftime('%Y-%m-%d %H:%M:%S')} "
                          f"(Max SSD: {max_ssd_value:.2f}).")
                
                    sudden_increase_found = True
                    break

            if not sudden_increase_found:
                print(f"Max trend after March occurs on {max_trend_date.strftime('%Y-%m-%d')} "
                      f"(Trend Value: {max_trend_value:.2f}, SSD: {max_trend_ssd:.2f}), but no sudden gradient increase found within {window} steps.")
        else:
            print("Max trend date not found in the dataset index.")

##### The anomaly should be the max of sharp increase in gradients or the day after or before it
    axes[0].scatter(max_ssd_date, Tb_std.loc[max_ssd_date, 'SSD'], color='tab:pink', marker="D", s=100, label=f'First Sharp SSD Increase after Max Trend: {max_ssd_value:.2f} K')
    axes[0].legend(loc='center right')

    # Add Tb and DAV on Secondary Axis (Right)
    ax2 = axes[0].twinx()
    ax2.plot(DAV_df.index, DAV_df['DAV'], label='DAV Time Series', color='black', linewidth=2)
    ax2.plot(Tb_nearest.index, Tb_nearest['TB'], label='TB Time Series', color='orange', linewidth=1.5)
    ax2.plot(swe_df.index, swe_df['value'], label='SWE (mm)', color='purple', linewidth=3, zorder=1)
    ax2.axvline(x=max_swe_date, color='black', linestyle='--', label=f'Max SWE on day {max_swe_day_of_year}', linewidth=2)
    ax2.plot(filtered_temp_df.index, filtered_temp_df['value'], label='Temp (K)', color='tab:red', zorder=2)
    ax2.axhline(y=268.15, color='yellow', linestyle='--', linewidth=2, label='Air Temperature Threshold (268.15 K)')
    ax2.axhline(y=Tb_threshold, color='gray', linestyle='--', 
            label=f'TB Threshold: {Tb_threshold} K', linewidth=2)
    ax2.axhline(y=DAV_threshold, color='red', linestyle='--', 
            label=f'DAV Threshold (90th): {DAV_threshold:.2f} K', linewidth=2)
    ax2.set_ylabel('DAV/TB (K)', fontsize=14, color='black')
    ax2.legend(loc='upper right')

    # --- Plot Gradient on Bottom Subplot ---
    # Use real dates for the gradient x-axis
    gradient_dates = Tb_std.index
    axes[1].plot(gradient_dates, gradient, color='tab:blue', label='Gradient', linewidth=1.5)
    axes[1].axhline(y=pos_threshold, color='green', linestyle='--', 
                    label=f'Positive Threshold: {pos_threshold:.2f}')
    #axes[1].axhline(y=neg_threshold, color='red', linestyle='--', 
                    #label=f'Negative Threshold: {neg_threshold:.2f}')
    axes[1].set_title('Gradient of SSD Time Series', fontsize=16)
    axes[1].set_ylabel('Gradient', fontsize=14)
    axes[1].grid(True)

    # Highlight valid anomaly points on the gradient plot
    validanamoly = anomaly_after_march[anomaly_after_march < intersection_date]
    valid_indices = [Tb_std.index.get_loc(date) for date in validanamoly]
    valid_indices = valid_indices[0]
    axes[1].scatter(gradient_dates[valid_indices], gradient[valid_indices], 
                    color='tab:pink', marker="D", s=100, label='First Sharp Increase Exceeding Positive Threshold of Gradient, after Max SSD Trend')
    axes[1].legend()

    # Format x-axis for date alignment
    axes[1].set_xlabel('Date', fontsize=14)
    
    plt.title(f'SSD Analysis for Snowmelt Detection, {Site}, {year}')  # Plot title

    # Adjust layout and show the plots
    plt.tight_layout()
    
    # Save the plot to the specified path (include bbox_extra_artists)
    plt.savefig(save_path, bbox_inches='tight')
    plt.show()
# Out:
# Positive Threshold: 0.9928207213524729
# Negative Threshold: -0.9979809706564993
# Detected valid positive-to-negative threshold dates:
# DatetimeIndex(['2003-04-10 18:00:00', '2003-04-12 18:00:00', '2003-04-14 06:00:00', '2003-04-24 06:00:00',
#                '2003-04-29 18:00:00'],
#               dtype='datetime64[ns]', freq=None)
# Max trend after March occurs on 2003-04-09 18:00:00 (Trend Value: 3.70, SSD: 4.51).
# Sudden gradient increase detected on 2003-04-10 18:00:00 (SSD: 6.38).
# Actual SSD increase occurs on 2003-04-10 18:00:00 (Max SSD: 6.38).

# %%
#Above this percentile, after max trend: Maybe MOD?
percentile_99 = Tb_std['SSD'].quantile(0.993)
percentile_99

# %% [markdown]
# # Create data frames of MOD and EHD

# %%
## MOD of the GRD pixel - avg all years
MOD_DOY_GRD_df, meltflag_GRD_df, EHD_DOY_GRD_df, EHDflag_GRD_df = MOD_array(
    datadir_GRD, prefix_GRD, data_GRD, DAV_GRD, rows_cols_GRD, 
    subYears, window, MOD_count, EHD_window, EHD_count, DAV_threshold, Tb_threshold)
MOD_DOY_GRD_df

# %% [markdown]
# # the meltflag dataframe
#
# Has an entry for each date (morning and evening) on rows, and for each pixel on columns
#
# It contains a 1 for any location/date that the melt criteria were met

# %%
meltflag_GRD_df

# %%
# sir MOD array - MOD will be in day of year (DOY) #changeback to Years for all years
MOD_DOY_df, meltflag_df, EHD_DOY_df, EHDflag_df = MOD_array(
    datadir_SIR, prefix_SIR, data_SIR, DAV_SIR, rows_cols_env, 
    subYears, window, MOD_count, EHD_window, EHD_count, DAV_threshold, Tb_threshold)
EHD_DOY_df

# %% [markdown]
# # Make a histogram of the MODs for a selected year

# %%
fig,ax = plt.subplots()
MOD_DOY_GRD_df.hist(ax=ax,column=2003)
ax.set_title('MOD Histogram, area=%s, year=%s' % (Site, str(year)))
ax.set_xlabel('DOY')

# %% [markdown]
# # Notes about changes from original notebooks:
#
# The old notebooks used to call MOD_array to get the average MOD for a set of years
# and then call MOD_array_year for a given year of interest.
#
# Now we just call MOD_array for SIR data and GRD data, and get back a data frame with
# MOD columns for each individual year, and one column for the avg MOD for all the years.
#
# This runs much faster, and can be saved and just re-read from a saved file on disk.
#
# The old notebooks only calculated MOD, the current versions of the MOD_array function also calculate EHD.
#
# You might decide to change MOD_array to only do one or the other based on an input switch if you don't always
# want both calculations.
#
# Now we are setting up to save these data and the way to read them in another notebook is:
#
# new = pd.read_pickle(MOD_DOY_filename)

# %% [markdown]
# # Save the MOD by year data frames for SIR and GRD to pickle files
#
# Also saving geolocation and melt onset flag data frames

# %%
if not os.path.isdir(outDir):
    os.makedirs(outDir)

# Set a short string in the filename to indicate whether window was the indexer function or a plain integer
if isinstance(window, int):
    rollingSumLabel = 'end'
else:
    rollingSumLabel = 'beg'
    
MODinfo = "MOD_C%1dW%02d%sT%03dD%02d" % (
    MOD_count, MOD_window, rollingSumLabel, Tb_threshold, DAV_threshold)  
meltflaginfo = "meltflag_C%1dW%02d%sT%03dD%02d" % (
    MOD_count, MOD_window, rollingSumLabel, Tb_threshold, DAV_threshold) 

sirMODBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, 
    subYears[0], subYears[-1], MODinfo)
grdMODBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, 
    subYears[0], subYears[-1], MODinfo)

sirmeltflagBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, 
    subYears[0], subYears[-1], meltflaginfo)
grdmeltflagBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, 
    subYears[0], subYears[-1], meltflaginfo)

filename = "%s.pkl" % (sirMODBasename)
MOD_DOY_df.to_pickle(filename)
print("MOD_DOY dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (grdMODBasename)
MOD_DOY_GRD_df.to_pickle(filename)
print("MOD_DOY_GRD dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (sirmeltflagBasename)
meltflag_df.to_pickle(filename)
print("meltflag_df dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (grdmeltflagBasename)
meltflag_GRD_df.to_pickle(filename)
print("meltflag_GRD_df dataframe saved to %s\n" % filename)

# %% [markdown]
# # Save the EHD by year data frames for SIR and GRD to pickle files
#
# Also saving geolocation and EHD flag data frames

# %%
if not os.path.isdir(outDir):
    os.makedirs(outDir)

# Set a short string in the filename to indicate whether window was the indexer function or a plain integer
if isinstance(EHD_window, int):
    rollingSumLabel = 'end'
else:
    rollingSumLabel = 'beg'
    
EHDinfo = "EHD_C%1dW%02d%sT%03dD%02d" % (
    EHD_count, EHD_window, rollingSumLabel, Tb_threshold, DAV_threshold)  
EHDflaginfo = "EHDflag_C%1dW%02d%sT%03dD%02d" % (
    EHD_count, EHD_window, rollingSumLabel, Tb_threshold, DAV_threshold) 

sirEHDBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, 
    subYears[0], subYears[-1], EHDinfo)
grdEHDBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, 
    subYears[0], subYears[-1], EHDinfo)

sirEHDflagBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, 
    subYears[0], subYears[-1], EHDflaginfo)
grdEHDflagBasename = "%s/%s.%s.%s.%s.%s.%s-%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, 
    subYears[0], subYears[-1], EHDflaginfo)

filename = "%s.pkl" % (sirEHDBasename)
EHD_DOY_df.to_pickle(filename)
print("EHD_DOY dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (grdEHDBasename)
EHD_DOY_GRD_df.to_pickle(filename)
print("EHD_DOY_GRD dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (sirEHDflagBasename)
EHDflag_df.to_pickle(filename)
print("EHDflag_df dataframe saved to %s\n" % filename)

filename = "%s.pkl" % (grdEHDflagBasename)
EHDflag_GRD_df.to_pickle(filename)
print("EHDflag_GRD_df dataframe saved to %s\n" % filename)

# %% [markdown]
# # Optionally, save the MOD for each year as a geotiff

# %%
# Take the subYears date range out of the basename strings, so that the geotiff routine can add the year itself
sirMODBasename = "%s/%s.%s.%s.%s.%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, MODinfo)
grdMODBasename = "%s/%s.%s.%s.%s.%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, MODinfo)

outSIR = write_df_to_geotiff(MOD_DOY_df, data_SIR['gpd'], sirMODBasename, verbose=True)
outGRD = write_df_to_geotiff(MOD_DOY_GRD_df, data_GRD['gpd'], grdMODBasename, verbose=True)

# %% [markdown]
# # Optionally, save the EHD for each year as a geotiff

# %%
# Take the subYears date range out of the basename strings, so that the geotiff routine can add the year itself
sirEHDBasename = "%s/%s.%s.%s.%s.%s.%s" % (
    outDir, data_SIR['gpd'], region, SiteLabel, sat_SIR, channel_SIR, EHDinfo)
grdEHDBasename = "%s/%s.%s.%s.%s.%s.%s" % (
    outDir, data_GRD['gpd'], region, SiteLabel, sat_GRD, channel_GRD, EHDinfo)

outSIR = write_df_to_geotiff(EHD_DOY_df, data_SIR['gpd'], sirEHDBasename, verbose=True)
outGRD = write_df_to_geotiff(EHD_DOY_GRD_df, data_GRD['gpd'], grdEHDBasename, verbose=True)

# %% [markdown]
# # TODO: Other things to potentially save here
#
# #Examples include: saving the DAV, or saving the std dev
